# %% [markdown]
# # Caso Ingeniería de Datos
# ## Exploración de datos
#
#
# *Diego Morales*
# **15/11/2025**
#
# ---

# %%
import pandas as pd
import numpy as np
import os

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.2.6

# %% [markdown]
# ### 1. Importación de datos

# %%
raw_path = 'data/raw/'
raw_file = 'data_entrega_productos.csv'
raw_filepath = os.path.join(raw_path, raw_file)

df = pd.read_csv(raw_filepath, sep=',')
print(df.shape)
df.head()
# Out:
# (379, 9)
#   pais  fecha_proceso  transporte    ruta tipo_entrega  material   precio  \
# 0   GT       20250513    67053596  919885         ZPRE  AA004003  3195.54
# 1   GT       20250513    67053596  919885         ZPRE  BA018426   529.99
# 2   GT       20250513    67053610  919885          Z04  BA018426  7799.74
# 3   GT       20250513    67053610  919885          Z04  BA018426    25.25
# 4   GT       20250513    67053610  919885          Z04  AA004005  1537.50
#
#    cantidad unidad
# 0     100.0     CS
# 1      20.0     CS
# 2     103.0     CS
# 3       2.0     ST
# 4      15.0     CS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pais           379 non-null    object
#  1   fecha_proceso  379 non-null    int64
#  2   transporte     379 non-null    int64
#  3   ruta           379 non-null    int64
#  4   tipo_entrega   379 non-null    object
#  5   material       361 non-null    object
#  6   precio         379 non-null    float64
#  7   cantidad       379 non-null    float64
#  8   unidad         379 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 26.8+ KB

# %%
df.describe(include='all')
# Out:
#        pais  fecha_proceso    transporte          ruta tipo_entrega  material  \
# count   379   3.790000e+02  3.790000e+02  3.790000e+02          379       361
# unique    6            NaN           NaN           NaN            5        32
# top      SV            NaN           NaN           NaN         ZPRE  AA875142
# freq    162            NaN           NaN           NaN          183        42
# mean    NaN   2.025034e+07  6.705278e+07  3.183348e+06          NaN       NaN
# std     NaN   9.993655e+01  5.472517e+02  1.824361e+06          NaN       NaN
# min     NaN   2.025011e+07  6.705026e+07  9.198850e+05          NaN       NaN
# 25%     NaN   2.025031e+07  6.705266e+07  2.161885e+06          NaN       NaN
# 50%     NaN   2.025032e+07  6.705285e+07  2.710948e+06          NaN       NaN
# 75%     NaN   2.025032e+07  6.705285e+07  2.710948e+06          NaN       NaN
# max     NaN   2.025060e+07  6.705395e+07  8.200894e+06          NaN       NaN
#
#                precio    cantidad unidad
# count      379.000000  379.000000    379
# unique            NaN         NaN      2
# top               NaN         NaN     CS
# freq              NaN         NaN    271
# mean      8347.186016   22.770449    NaN
# std      27123.102300   89.056771    NaN
# min          0.000000    1.000000    NaN
# 25%         17.280000    2.000000    NaN
# 50%        416.670000   10.000000    NaN
# 75%       3000.000000   20.000000    NaN
# max     156400.000000  960.000000    NaN

# %% [markdown]
# ### 2. Analisis por variable

# %% [markdown]
# #### fecha_proceso

# %%
# se convierte el campo a fecha
df['fecha_proceso'] = pd.to_datetime(df.fecha_proceso, format='%Y%m%d', errors='coerce')

# %%
# se revisan los rangos de fechass
df.fecha_proceso.describe()
# Out:
# count                              379
# mean     2025-03-24 17:21:03.324538112
# min                2025-01-14 00:00:00
# 25%                2025-03-14 00:00:00
# 50%                2025-03-25 00:00:00
# 75%                2025-03-25 00:00:00
# max                2025-06-02 00:00:00
# Name: fecha_proceso, dtype: object

# %% [markdown]
# #### pais

# %%
# revision de distribucion valores para pais
# se determina que los codigos de pais son validos
# no hay nulos
(df
    .pais
    .value_counts(dropna=False, normalize=True)
    .mul(100)
)
# Out:
# pais
# SV    42.744063
# HN    31.398417
# EC    12.664908
# JM     9.498681
# GT     3.166227
# PE     0.527704
# Name: proportion, dtype: float64

# %% [markdown]
# #### tipo_entrega

# %%
# distribucion de valores para tipo de entrega
# se encuentran valores no validos segun instruciones: COBR y ZVE1
(df
    .tipo_entrega
    .value_counts(dropna=False, normalize=True)
    .mul(100)
)
# Out:
# tipo_entrega
# ZPRE    48.284960
# Z04     19.788918
# COBR    12.137203
# Z05     10.290237
# ZVE1     9.498681
# Name: proportion, dtype: float64

# %%
# se definen valores validos para tipo de entrega
entregas_rutina = ['ZPRE', 'ZVE1']
entregas_bonificadas = ['Z04', 'Z05']

tipo_entrega_validos = entregas_rutina + entregas_bonificadas

# distribucion de valores validos para tipo de entrega
# no se encuentran nulos
(df
    [df.tipo_entrega.isin(tipo_entrega_validos)]
    .tipo_entrega
    .value_counts(dropna=False, normalize=True)
    .mul(100)
)
# Out:
# tipo_entrega
# ZPRE    54.954955
# Z04     22.522523
# Z05     11.711712
# ZVE1    10.810811
# Name: proportion, dtype: float64

# %% [markdown]
# #### unidad

# %%
# distribucion de valores para unidad
# no se encuentran valores nuloso invalidos
(df
    .unidad
    .value_counts(dropna=False, normalize=True)
    .mul(100)
)
# Out:
# unidad
# CS    71.503958
# ST    28.496042
# Name: proportion, dtype: float64

# %% [markdown]
# #### material

# %%
# frecuencia de materiales
# se evidencian 18 valores NaN
(df
    .material
    .value_counts(dropna=False, normalize=False)
    .head(10)
)
# Out:
# material
# AA875142    42
# AA015008    36
# AA131113    36
# AA015011    36
# AA041001    21
# AA317050    21
# NaN         18
# AA059001    14
# AA001001    14
# AA015001    12
# Name: count, dtype: int64

# %%
# se revisa si los valores nulos se asocian a algun comportamiento
# sin embargo, no se encuentra un patron evidente y parecen ser aleatorios
df[df.material.isna()].sort_values(['transporte', 'ruta', 'precio'])
# Out:
#     pais fecha_proceso  transporte     ruta tipo_entrega material   precio  \
# 10    EC    2025-02-17    67051860  4511092         COBR      NaN  1812.44
# 82    EC    2025-02-17    67051860  4511092         ZPRE      NaN  1812.44
# 150   EC    2025-02-17    67051860  4511092          Z05      NaN  1812.44
# 218   EC    2025-02-17    67051860  4511092         ZPRE      NaN  1812.44
# 64    HN    2025-03-14    67052658  2710948         COBR      NaN  4003.00
# 136   HN    2025-03-14    67052658  2710948         COBR      NaN  4003.00
# 204   HN    2025-03-14    67052658  2710948          Z04      NaN  4003.00
# 272   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4003.00
# 316   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4003.00
# 360   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4003.00
# 377   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4003.00
# 65    HN    2025-03-14    67052658  2710948         COBR      NaN  4424.86
# 137   HN    2025-03-14    67052658  2710948         COBR      NaN  4424.86
# 205   HN    2025-03-14    67052658  2710948          Z04      NaN  4424.86
# 273   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4424.86
# 317   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4424.86
# 361   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4424.86
# 378   HN    2025-03-14    67052658  2710948         ZPRE      NaN  4424.86
#
#      cantidad unidad
# 10        1.0     ST
# 82        1.0     ST
# 150       1.0     ST
# 218       1.0     ST
# 64        1.0     ST
# 136       1.0     ST
# 204       1.0     ST
# 272       1.0     ST
# 316       1.0     ST
# 360       1.0     ST
# 377       1.0     ST
# 65        1.0     ST
# 137       1.0     ST
# 205       1.0     ST
# 273       1.0     ST
# 317       1.0     ST
# 361       1.0     ST
# 378       1.0     ST

# %% [markdown]
# #### transporte

# %%
# distribucion de valores para transporte
# no se encuentran valores nulos
(df
    .transporte
    .value_counts(dropna=False, normalize=False)
)
# Out:
# transporte
# 67052854    162
# 67052658    119
# 67051860     48
# 67053946     36
# 67053610      8
# 67053596      2
# 67053638      2
# 67050264      2
# Name: count, dtype: int64

# %% [markdown]
# #### ruta

# %%
# distribucion de valores para ruta
# no se encuentran valores nulos
(df
    .ruta
    .value_counts(dropna=False, normalize=False)
)
# Out:
# ruta
# 2161885    162
# 2710948    119
# 4511092     48
# 8200894     36
# 919885      12
# 5428813      2
# Name: count, dtype: int64

# %%
df.groupby(['transporte', 'ruta']).size()
# Out:
# transporte  ruta
# 67050264    5428813      2
# 67051860    4511092     48
# 67052658    2710948    119
# 67052854    2161885    162
# 67053596    919885       2
# 67053610    919885       8
# 67053638    919885       2
# 67053946    8200894     36
# dtype: int64

# %% [markdown]
# #### cantidad

# %%
df.cantidad.describe()
# Out:
# count    379.000000
# mean      22.770449
# std       89.056771
# min        1.000000
# 25%        2.000000
# 50%       10.000000
# 75%       20.000000
# max      960.000000
# Name: cantidad, dtype: float64

# %%
df[df.unidad=='CS'].cantidad.describe()
# Out:
# count    271.000000
# mean      19.206642
# std       34.418364
# min        2.000000
# 25%        5.000000
# 50%       10.000000
# 75%       30.000000
# max      503.000000
# Name: cantidad, dtype: float64

# %%
df[df.unidad=='ST'].cantidad.describe()
# Out:
# count    108.000000
# mean      31.712963
# std      157.848623
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        8.000000
# max      960.000000
# Name: cantidad, dtype: float64

# %% [markdown]
# #### precio

# %%
df.precio.describe()
# Out:
# count       379.000000
# mean       8347.186016
# std       27123.102300
# min           0.000000
# 25%          17.280000
# 50%         416.670000
# 75%        3000.000000
# max      156400.000000
# Name: precio, dtype: float64

# %%
# revision de precios iguales a cero
df[df.precio==0]
# Out:
#     pais fecha_proceso  transporte     ruta tipo_entrega  material  precio  \
# 16    EC    2025-02-17    67051860  4511092         COBR  AA004001     0.0
# 17    EC    2025-02-17    67051860  4511092         COBR  AA004002     0.0
# 18    EC    2025-02-17    67051860  4511092         COBR  AA004003     0.0
# 19    EC    2025-02-17    67051860  4511092         COBR  AA004012     0.0
# 36    SV    2025-03-25    67052854  2161885         ZPRE  AA015008     0.0
# ..   ...           ...         ...      ...          ...       ...     ...
# 359   HN    2025-03-14    67052658  2710948         ZPRE  AA317050     0.0
# 370   HN    2025-03-14    67052658  2710948         ZPRE  EN001001     0.0
# 371   HN    2025-03-14    67052658  2710948         ZPRE  CA001099     0.0
# 375   HN    2025-03-14    67052658  2710948         ZPRE  AA041001     0.0
# 376   HN    2025-03-14    67052658  2710948         ZPRE  AA317050     0.0
#
#      cantidad unidad
# 16       10.0     CS
# 17       10.0     CS
# 18       10.0     CS
# 19       10.0     CS
# 36       10.0     CS
# ..        ...    ...
# 359       8.0     ST
# 370      10.0     CS
# 371      10.0     ST
# 375       1.0     ST
# 376       8.0     ST
#
# [74 rows x 9 columns]

# %%
# se revisa si los precios iguales a cero se asocian a algun comportamiento
(df
    [df.precio==0]
    .groupby(['pais', 'transporte', 'ruta'])
    .size()
)
# Out:
# pais  transporte  ruta
# EC    67051860    4511092    16
# HN    67052658    2710948    28
# SV    67052854    2161885    30
# dtype: int64

# %%
# verificacion de tipo de entrega para precios 0
(df
    [df.precio==0]
    .tipo_entrega
    .value_counts()
)
# Out:
# tipo_entrega
# ZPRE    39
# Z04     14
# COBR    12
# Z05      9
# Name: count, dtype: int64

# %%
# en promedio, ningun tipo de entrega tiene precio cero
# por lo que parece ser un error en el ingreso de datos
# o alguna particularidad del negocio que no esta documentada
df.groupby('tipo_entrega').precio.mean()
# Out:
# tipo_entrega
# COBR     3052.420217
# Z04      1247.421600
# Z05       331.378974
# ZPRE     1946.890164
# ZVE1    71122.524167
# Name: precio, dtype: float64

# %%
# visualizacion de buckets de precio
df.precio.value_counts(bins=[-0.01, 0, 100, 10000, 100000, 1e6]).sort_index()
# Out:
# (-0.011, 0.0]             74
# (0.0, 100.0]              90
# (100.0, 10000.0]         163
# (10000.0, 100000.0]       37
# (100000.0, 1000000.0]     15
# Name: count, dtype: int64
